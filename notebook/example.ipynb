# %% [markdown]
# # Get Hansard data for 15 March 2021
#
# Below is a screenshot of Hansard data for 15 March 2021. We are interested in the highlighted red box. The blue box shows the **folder**. The orange box shows a **sub folder**. Within the folder or sub folder are **cards** (highlighted by stars) which link to a page containing the text.
#
# ![Folders](meta/folders.png)
#
# Below shows an example of the text contained within a card URL. We take all paragraph text, as highlighted in the green boxes.
#
# ![Folders](meta/card.png)
#
# All results are then saved to a dataframe.
#
# Below we break down the code for you to see it in action. The original code is in src/main.py

# %%
from datetime import datetime, timedelta

import requests
from bs4 import BeautifulSoup as Soup
import pandas as pd

# %%
#Set a date
date = '2021-03-15'

# %%
#Download data from the page

url = 'https://hansard.parliament.uk/commons/' + date
response = requests.get(url, timeout=5)
page_content = Soup(response.content, "html.parser")
folders = page_content.find_all("div", attrs={"class": "card-folder"})

# %% [markdown]
# Folders is just the HTML data from the selected area of the page (blue areas in the first screenshot). We do this by using the attribute selection in BeautifulSoup and searching on the card-folder class.

# %%
folders
# Out:
# [<div class="card-folder">
#  <a class="toggle" data-expand-on-load="true" href="#">
#  <h2>Commons Chamber</h2>
#  <p>Record of debates that happened in the House of Commons main chamber.</p>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/72DFF73F-9E31-4651-935A-47EE0BFFD2B9/HouseOfCommons">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      House of Commons
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <a class="card card-section" href="/commons/2021-03-15/debates/0AA3FB1E-8056-49FC-923D-BBAF53D50E66/Prayers">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Prayers
#                      <span class="sr-only">(item number 2)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="card-folder card-folder-section">
#  <a class="toggle" href="#">
#  <h3>Oral Answers to Questions</h3>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/3918BF70-A275-405D-B0B6-04CAB8610FDB/OralAnswersToQuestions">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#  <span class="light">View all</span> Oral Answers to Questions
#                              </div>
#  </div>
#  </div>
#  </a>
#  <div class="card-folder card-folder-section">
#  <a class="toggle" href="#">
#  <h3>Defence</h3>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/6ECDE577-00AD-4C01-BB1D-64272D5005A8/MilitaryHousingAnningtonHomes">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Military Housing: Annington Homes
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <a class="card card-section" href="/commons/2021-03-15/debates/705F924A-0322-4F84-83B9-B5BEF71D5AE9/DefenceEstateOptimisationProgramme">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Defence Estate Optimisation Programme
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <a class="card card-section" href="/commons/2021-03-15/debates/310C4DC8-419A-46DC-BC1E-7716F74562DD/CyberWarfare">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Cyber Warfare
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <a class="card card-section" href="/commons/2021-03-15/debates/59D305EF-3A73-4668-959A-897811D772DC/VeteransOverseas">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Veterans Overseas
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <a class="card card-section" href="/commons/2021-03-15/debates/3C073891-8C83-4764-93EA-25C0EEA2EFCB/ArmedForcesPersonnel">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Armed Forces Personnel
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <a class="card card-section" href="/commons/2021-03-15/debates/B5B3376A-8D0D-4A80-891D-4F8238A30A5E/SupportForVeterans">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Support for Veterans
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <a class="card card-section" href="/commons/2021-03-15/debates/A90E070F-3FC0-4714-8ACA-226E2DE2FE2D/Covid-19NHSSupport">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Covid-19: NHS Support
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <a class="card card-section" href="/commons/2021-03-15/debates/3B499FF9-5B94-4609-87C3-46A3C61B3E2E/Covid-19VaccineRoll-Out">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Covid-19: Vaccine Roll-out
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <a class="card card-section" href="/commons/2021-03-15/debates/D3E78BC6-B4F7-4ABB-AC3E-2471939B2E12/ArmyPersonnel">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Army Personnel
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <a class="card card-section" href="/commons/2021-03-15/debates/62EEA8AD-40FD-4506-AF30-26DF1B8C9976/MentalHealthSupportForVeterans">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Mental Health Support for Veterans
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <a class="card card-section" href="/commons/2021-03-15/debates/DDF95718-D168-4E14-84D1-141A517C68F2/SubmarineDismantlingProgramme">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Submarine Dismantling Programme
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <a class="card card-section" href="/commons/2021-03-15/debates/C138F117-A43E-4435-A0B7-B2E67635E11E/ServiceJusticeSystem">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <a class="card card-section" href="/commons/2021-03-15/debates/8D4B8782-7BA5-475B-A48A-370859B78209/VaccinePassports">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Vaccine Passports
#                      <span class="sr-only">(item number 2)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <a class="card card-section" href="/commons/2021-03-15/debates/04A8B933-1B55-46A9-9A65-212FC655EA29/Covid-19ImpactOnEducation">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                       Covid-19: Impact on Education
#                      <span class="sr-only">(item number 3)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>,
#  <div class="card-folder">
#  <a class="toggle" data-expand-on-load="false" href="#">
#  <h2>Written Statements</h2>
#  <p>Written statements are normally used to put the day-to-day business of government on the official record and in the public domain.</p>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/21031551000001/WrittenStatements">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Written Statements
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="card-folder card-folder-section">
#  <a class="toggle" href="#">
#  <h3>Defence</h3>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/21031551000007/Single-SourceDefenceContracts">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Single-source Defence Contracts
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <div class="card-folder card-folder-section">
#  <a class="toggle" href="#">
#  <h3>Home Department</h3>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/21031551000008/IndependentChiefInspectorOfBordersAndImmigration">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Independent Chief Inspector of Borders and Immigration
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <div class="card-folder card-folder-section">
#  <a class="toggle" href="#">
#  <h3>International Trade</h3>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/21031551000009/FutureTradingRelationshipWithAustralia">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Future Trading Relationship with Australia
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <div class="card-folder card-folder-section">
#  <a class="toggle" href="#">
#  <h3>Transport</h3>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/21031551000010/NationalBusStrategyEngland(OutsideLondon)">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      National Bus Strategy: England (Outside London)
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-folder card-folder-section">
#  <a class="toggle" href="#">
#  <h3>Defence</h3>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/21031551000007/Single-SourceDefenceContracts">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Single-source Defence Contracts
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>,
#  <div class="card-folder card-folder-section">
#  <a class="toggle" href="#">
#  <h3>Home Department</h3>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/21031551000008/IndependentChiefInspectorOfBordersAndImmigration">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Independent Chief Inspector of Borders and Immigration
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>,
#  <div class="card-folder card-folder-section">
#  <a class="toggle" href="#">
#  <h3>International Trade</h3>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/21031551000009/FutureTradingRelationshipWithAustralia">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Future Trading Relationship with Australia
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>,
#  <div class="card-folder card-folder-section">
#  <a class="toggle" href="#">
#  <h3>Transport</h3>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/21031551000010/NationalBusStrategyEngland(OutsideLondon)">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      National Bus Strategy: England (Outside London)
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>,
#  <div class="card-folder">
#  <a class="toggle" data-expand-on-load="false" href="#">
#  <h2>Petitions</h2>
#  <p>Debates about petitions that have been submitted by the public.</p>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/21031558000001/Petition">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Petition
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="card-folder card-folder-section">
#  <a class="toggle" href="#">
#  <h3>Observations</h3>
#  </a>
#  <div class="contents collapse">
#  <div class="card-folder card-folder-section">
#  <a class="toggle" href="#">
#  <h3>Transport</h3>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/21031558000018/ReopeningOfLeamsideRailLine">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Reopening of Leamside rail line
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-folder card-folder-section">
#  <a class="toggle" href="#">
#  <h3>Observations</h3>
#  </a>
#  <div class="contents collapse">
#  <div class="card-folder card-folder-section">
#  <a class="toggle" href="#">
#  <h3>Transport</h3>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/21031558000018/ReopeningOfLeamsideRailLine">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Reopening of Leamside rail line
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-folder card-folder-section">
#  <a class="toggle" href="#">
#  <h3>Transport</h3>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/21031558000018/ReopeningOfLeamsideRailLine">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Reopening of Leamside rail line
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>,
#  <div class="card-folder">
#  <a class="toggle" data-expand-on-load="false" href="#">
#  <h2>Ministerial Corrections</h2>
#  <p>Ministerial corrections to answers to questions.</p>
#  </a>
#  <div class="contents collapse">
#  <a class="card card-section" href="/commons/2021-03-15/debates/21031526000001/MinisterialCorrection">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Ministerial Correction
#                      <span class="sr-only">(item number 1)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  <a class="card card-section" href="/commons/2021-03-15/debates/9583E823-941F-4760-B175-D7B7C5C92C46/WomenAndEqualities">
#  <div class="card-inner">
#  <div class="content">
#  <div class="primary-info">
#                      Women and Equalities
#                      <span class="sr-only">(item number 2)</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>]

# %%
folder_name = ''
folder_desc = ''

folder_name_lst = []
folder_desc_lst = []
sub_folder_name_lst = []
card_lst = []
link_lst = []
text_lst = []

# %% [markdown]
# For each folder (blue box) we then run our code to search for sub folders and cards. We then get the URL for each card and grab the text.

# %%
for folder in folders:
    # Searching just for H2 text which denotes the folder name of the publication
    if len(folder.find_all('h2')) > 0:
        folder_name = folder.text.split("\n")[2]
        folder_desc = folder.text.split("\n")[3]
        sub_folder_name = ''

    else:
        # Otherwise it's a subfolder
        sub_folder_name = folder.text.split("\n")[2]

    cards = folder.find_all("a", attrs={"class": "card card-section"})
    for card in cards:
        # Gets name of the card
        card_lst.append(card.text.split('\r\n')[1].strip())

        # Gets each card in each folder, finds it's URL link
        link = 'https://hansard.parliament.uk/' + card.attrs.get('href')
        folder_name_lst.append(folder_name)
        folder_desc_lst.append(folder_desc)
        sub_folder_name_lst.append(sub_folder_name)
        link_lst.append(link)

        # Goes to the relevant URL
        response = requests.get(link, timeout=5)
        page_content = Soup(response.content, "html.parser")
        content = page_content.find("div", attrs={"class": "col-lg-9 primary-content"})
        paras = content.find_all("p")

        text_out = ''
        for para in paras:
            # Collects all relevant text for the page
            if len(para.text) > 5:
                text_out = text_out + ' ' + para.text
        text_lst.append(text_out)

# %% [markdown]
# Now we have many lists comprising the folder names, URL links and text within the cards. For example...

# %%
print(folder_name_lst[3] +
      '\n' + 
      folder_desc_lst[3] +
      '\n' + 
      sub_folder_name_lst[3] +
      '\n' + 
      card_lst[3] +
      '\n' + 
      link_lst[3] +
      '\n' +
      text_lst[3])
# Out:
# Commons Chamber
# Record of debates that happened in the House of Commons main chamber.
#
# Military Housing: Annington Homes
# https://hansard.parliament.uk//commons/2021-03-15/debates/6ECDE577-00AD-4C01-BB1D-64272D5005A8/MilitaryHousingAnningtonHomes
#   What recent discussions his Department has had with representatives of Annington Homes on the sale of military housing.  (913319) Before I turn to Question 1, on behalf of the Government I wish to pay tribute to Sergeant Gavin Hillier of the Welsh Guards, who tragically died in an accident during live-firing exercises in Wales earlier this month. Sergeant Hillier’s distinguished service throughout his career was a tribute not only to his own dedication to duty but to his family and to his regiment, who continue to prepare for operations in Iraq later this year. I thank my hon. Friend the Member for Orpington (Gareth Bacon) for his close interest in this issue, which is also actively pursued by my right hon. Friend the Member for Preseli Pembrokeshire (Stephen Crabb), my hon. Friends the Members for North West Cambridgeshire (Mr Vara) and for Devizes (Danny Kruger), and other colleagues. The Ministry of Defence longer has any ongoing military requirement for the homes, which we therefore intend to hand back to Annington, thereby helping to meet obligations under our agreements. I regret that, despite the MOD’s producing a significant package of support that we hoped might assist Annington to allow our tenants to remain in situ in many, although not all, cases, that was not a course that Annington felt able to pursue. I join the Minister and, I am sure, the whole House in expressing sympathy for the family and friends of Sergeant Hillier. A number of my constituents in Biggin Hill are keen to remain in their homes; is there no way that Annington Homes can facilitate that? If not, given that we are still battling the covid pandemic, is there any way in which the Minister can provide for a longer notice period to help to provide my constituents with greater certainty at this very difficult time? I am pleased to say that I have some good news for my hon. Friend and his constituents. I am pleased to confirm that, mindful of the representations made by my right hon. and hon. Friends, of the fact that we are talking about packages of houses rather than single units and of the ongoing covid restrictions, we will be extending the notice period to 31 March 2022. That will mean that civilian tenants will have received more than 18 months’ notice in total. Furthermore, Annington has confirmed that it has no in-principle objection to selling the properties to local authorities or other social housing providers. I stress that any such deals would be a commercial proposition between the social housing providers and Annington, but I hope that the additional time provided may help to enable such transactions to be progressed. I shall write to my hon. Friend and other affected MPs on this subject today.

# %% [markdown]
# Finally we just neatly add these to a dataframe.

# %%
df = pd.DataFrame(list(zip(folder_name_lst, folder_desc_lst, sub_folder_name_lst, card_lst, link_lst,
                           text_lst)),
                  columns=['Folder', 'Description', 'Subfolder', 'Card', 'Link', 'Text'])

df['date_collected'] = datetime.now().strftime('%d/%m/%Y')

df.head(5)
# Out:
#             Folder                                        Description  \
# 0  Commons Chamber  Record of debates that happened in the House o...
# 1  Commons Chamber  Record of debates that happened in the House o...
# 2  Commons Chamber  Record of debates that happened in the House o...
# 3  Commons Chamber  Record of debates that happened in the House o...
# 4  Commons Chamber  Record of debates that happened in the House o...
#
#   Subfolder                                   Card  \
# 0                                 House of Commons
# 1                                          Prayers
# 2
# 3                Military Housing: Annington Homes
# 4            Defence Estate Optimisation Programme
#
#                                                 Link  \
# 0  https://hansard.parliament.uk//commons/2021-03...
# 1  https://hansard.parliament.uk//commons/2021-03...
# 2  https://hansard.parliament.uk//commons/2021-03...
# 3  https://hansard.parliament.uk//commons/2021-03...
# 4  https://hansard.parliament.uk//commons/2021-03...
#
#                                                 Text date_collected
# 0   Monday 15 March 2021 The House met at half-pa...     30/03/2021
# 1   [Mr Speaker in the Chair] Virtual participati...     30/03/2021
# 2   The Secretary of State was asked—  What recen...     30/03/2021
# 3    What recent discussions his Department has h...     30/03/2021
# 4    What plans he has to review the defence esta...     30/03/2021

# %% [markdown]
# As shown, row 2 has no Card name. This is because the page it links to comprises all the text from a number of subsqeuent Cards such as Military Housing: Annington Homes and Defence Estate Optimisation Programme. Therefore, we will drop all rows where the Card field is empty.

# %%
df = df[df.Card != '']
df.head(5)
# Out:
#             Folder                                        Description  \
# 0  Commons Chamber  Record of debates that happened in the House o...
# 1  Commons Chamber  Record of debates that happened in the House o...
# 3  Commons Chamber  Record of debates that happened in the House o...
# 4  Commons Chamber  Record of debates that happened in the House o...
# 5  Commons Chamber  Record of debates that happened in the House o...
#
#   Subfolder                                   Card  \
# 0                                 House of Commons
# 1                                          Prayers
# 3                Military Housing: Annington Homes
# 4            Defence Estate Optimisation Programme
# 5                                    Cyber Warfare
#
#                                                 Link  \
# 0  https://hansard.parliament.uk//commons/2021-03...
# 1  https://hansard.parliament.uk//commons/2021-03...
# 3  https://hansard.parliament.uk//commons/2021-03...
# 4  https://hansard.parliament.uk//commons/2021-03...
# 5  https://hansard.parliament.uk//commons/2021-03...
#
#                                                 Text date_collected
# 0   Monday 15 March 2021 The House met at half-pa...     30/03/2021
# 1   [Mr Speaker in the Chair] Virtual participati...     30/03/2021
# 3    What recent discussions his Department has h...     30/03/2021
# 4    What plans he has to review the defence esta...     30/03/2021
# 5    What steps his Department is taking to reduc...     30/03/2021
